# %%
print("Hello World")
# Out:
# Hello World

# %%
filename = ['nov-12.txt','november-14.txt','Oct-17.txt','Nov-22.txt']

# %%
text = "Hi there you here ex_xample@example.com some more text here and there another@example.de"

# %%
import re 
pattern = re.compile("[^ ]+@[a-z]+.[a-z]+")
matches = pattern.findall(text)
matches
# Out:
# ['ex_xample@example.com', 'another@example.de']

# %%
## Meta Characters in Regular Expressions

| Meta Character | Description |
|---|---|
| `.` | Matches any single character (except newline). |
| `\` | Escapes a meta character to treat it as a literal character. |
| `[...]` | Matches any one character inside the brackets (or a range). |
| `+` | Matches the preceding element **one or more** times. |
| `?` | Matches the preceding element **zero or one** time. |
| `*` | Matches the preceding element **zero or more** times. |
| `{m,n}` | Matches the preceding element at least `m` and at most `n` times. |
| `^` | Matches the beginning of a line or string. |
| `$` | Matches the end of a line or string. |
| `[^...]` | Matches any one character **not** inside the brackets. |
| `...|...` | OR operator; matches either the left or right expression. |
| `()` | Groups expressions and can capture matched text. |
# Out:
#   Cell In[13], line 3
#     | Meta Character | Description |
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Extract URLs from Text

# %%
with open('urls.txt','r') as file:
    text = file.read()
    
print(text)
# Out:
# http://google.com
# https://example.com
# http://www.wikipedia.com
# http://pythonhow.com
# https://python.org

# %%
import re

pattern = re.compile('https?://(?:www.)?[^ \n]+\.com')
matches = pattern.findall(text)
matches
# Out:
# ['http://google.com',
#  'https://example.com',
#  'http://www.wikipedia.com',
#  'http://pythonhow.com']

# %% [markdown]
# ## Extract IP Addresses using regex

# %%
with open('ips.txt','r') as file:
    content = file.read()
print(content)
# Out:
# 912.131.120.111
# 912.131.134.000
# 912.131.129.129

# %%
pattern = re.compile("[0-9]{3}\.[0-9]{3}\.12[0-9]{1}\.[0-9]{3}")
matches = pattern.findall(content)
matches
# Out:
# ['912.131.120.111', '912.131.129.129']

# %% [markdown]
# ## Filter Filenames

# %%
from pathlib import Path 

root_dir = Path('files')
filenames = root_dir.iterdir()
filenames_str = [filename.name for filename in filenames]
filenames_str
# Out:
# ['billy_Nov-13.txt',
#  'Nov-12.txt',
#  'nov-20.txt',
#  'Nov-22.txt',
#  'november-14.txt',
#  'November-24.txt',
#  'Oct-17.txt']

# %%
import re

pattern = re.compile("nov[a-z]*-(?:[1-9]|1[0-9]|20).txt", re.IGNORECASE)
matches = [filename for filename in filenames_str if pattern.findall(filename)]
matches
# Out:
# ['billy_Nov-13.txt', 'Nov-12.txt', 'nov-20.txt', 'november-14.txt']

# %% [markdown]
# ## Find a word in Text

# %%
data=[
    "mr Jim Cloudy, Texas, 01091231, 1 dog 1 cat, jim.cloudy@example.com", 
    "mrs Anna Cloudy, Delhi, 2dogs 1fish bathlover@example.com",
    "Mrs. Sarah Prost, Baghdad, +4327629101, 1 hamster, 2 crocodiles",
    "Ms Beta Palm Ontario 08234211 12 cats, beta@example.com",
    "mr. Dog Bells texas 09234211 3 honey badgers alta_bells.example.com",
    "ms. Claudia More, Gujarat, 012311, 3 dogs",
    "mrs Alma Stills Delhi 01231981 1 dog",
    "mr Sen Kumar Delhi 3456 ants"
]

# %%
import re
 
pattern = re.compile(".*Delhi.*", re.IGNORECASE)
matches = [match for match in data if pattern.findall(match)]
print(matches)
# Out:
# ['mrs Anna Cloudy, Delhi, 2dogs 1fish bathlover@example.com', 'mrs Alma Stills Delhi 01231981 1 dog', 'mr Sen Kumar Delhi 3456 ants']

# %% [markdown]
# ## Find Lines Containing a Word and an Email Address

# %%
data=[
    "mr Jim Cloudy, Texas, 01091231, 1 dog 1 cat, jim.cloudy@example.com", 
    "mrs Anna Cloudy, Delhi, 2dogs 1fish bathlover@example.com",
    "Mrs. Sarah Prost, Baghdad, +4327629101, 1 hamster, 2 crocodiles",
    "Ms Beta Palm Ontario 08234211 12 cats, beta@example.com",
    "mr. Dog Bells texas 09234211 3 honey badgers alta_bells.example.com",
    "ms. Claudia More, Gujarat, 012311, 3 dogs",
    "mrs Alma Stills Delhi 01231981 1 dog",
    "mr Sen Kumar Delhi 3456 ants"
]

# %%
import re
 
pattern = re.compile(".*Delhi.*[^ ]+@[^ ]+\.[a-z]+", re.IGNORECASE)
matches = [match for match in data if pattern.findall(match)]
print(matches)
# Out:
# ['mrs Anna Cloudy, Delhi, 2dogs 1fish bathlover@example.com']

# %% [markdown]
# ## Find Lines Containing a Word and a Phone Number

# %%
data=[
    "mr Jim Cloudy, Texas, 01091231, 1 dog 1 cat, jim.cloudy@example.com", 
    "mrs Anna Cloudy, Delhi, 2dogs 1fish bathlover@example.com",
    "Mrs. Sarah Prost, Baghdad, +4327629101, 1 hamster, 2 crocodiles",
    "Ms Beta Palm Ontario 08234211 12 cats, beta@example.com",
    "mr. Dog Bells texas 09234211 3 honey badgers alta_bells.example.com",
    "ms. Claudia More, Gujarat, 012311, 3 dogs",
    "mrs Alma Stills Delhi 01231981 1 dog",
    "mr Sen Kumar Delhi 3456 ants"
]

# %%
import re
 
pattern = re.compile(".*Delhi.*[0|+][0-9]{4,50}", re.IGNORECASE)
matches = [match for match in data if pattern.findall(match)]
print(matches)
# Out:
# ['mrs Alma Stills Delhi 01231981 1 dog']

# %% [markdown]
# ## Find Lines Containing a Phone Number and an Email Address

# %%
data=[
    "mr Jim Cloudy, Texas, 01091231, 1 dog 1 cat, jim.cloudy@example.com", 
    "mrs Anna Cloudy, Delhi, 2dogs 1fish bathlover@example.com",
    "Mrs. Sarah Prost, Baghdad, +4327629101, 1 hamster, 2 crocodiles",
    "Ms Beta Palm Ontario 08234211 12 cats, beta@example.com",
    "mr. Dog Bells texas 09234211 3 honey badgers alta_bells.example.com",
    "ms. Claudia More, Gujarat, 012311, 3 dogs",
    "mrs Alma Stills Delhi 01231981 1 dog",
    "mr Sen Kumar Delhi 3456 ants"
]

# %%
import re
 
pattern = re.compile(".*Delhi.*([0|+][0-9]{4,50}|[^ ]+@[^ ]+.[a-z]+)", re.IGNORECASE)
matches = [match for match in data if pattern.findall(match)]
print(matches)
# Out:
# ['mrs Anna Cloudy, Delhi, 2dogs 1fish bathlover@example.com', 'mrs Alma Stills Delhi 01231981 1 dog']
